# %%
import pandas as pd
from scipy import sparse
import pandas as pd
import numpy as np
from numpy import var
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random
from matplotlib import pyplot as plt
from scipy.stats import norm
import numpy as np
from fitter import Fitter, get_common_distributions, get_distributions
from scipy import stats
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statistics
import math

#load data
ratings = pd.read_csv('dataset/ratings.csv')
moviesPartial = pd.read_csv('dataset/movies.csv')
moviesFull = pd.read_csv('dataset/movie_dataset.csv')

#drop duplicates
moviesFull.drop_duplicates(subset = 'title', inplace=True)

#drop columns that do nothing
ratings = ratings.drop(['timestamp'], axis = 1)
moviesPartial = moviesPartial.drop(['genres'],axis=1)

#all the users are to be tested
userRatings = []
for i in range(1,611):
    userRatings.append(ratings[ratings['userId'] ==i])

#remove the year and keep the name
moviesPartial['title'] = moviesPartial['title'].map(lambda string: string[:-7])

#drop duplicates
moviesPartial.drop_duplicates(subset = 'title', inplace=True)

#helper functions:
def get_title_from_movieId(tmp):
    return moviesPartial[moviesPartial["movieId"]== tmp]["title"].to_string(index=False)

def checkTitle(tmp):
    if(tmp not in list(moviesFull["title"])):
        #The word "the" is being apended to the ends of titles
        tmp = tmp[-3:] +" "+ tmp[:-5]
        return moviesFull[moviesFull["title"] == tmp]["title"].to_string(index=False)
    else:
        return moviesFull[moviesFull["title"] == tmp]["title"].to_string(index=False)



#used to filter out movies that are not in both data sets
newUserTitles = []
newUserRatings = []
for userRating in userRatings:
    temp1 = []
    temp2 = []
    for rating, id in zip(list(userRating["rating"]), list(userRating["movieId"])):
        title = get_title_from_movieId(id)
        checked = checkTitle(title)
        if(checked != 'Series([], )'):
            temp1.append(checked)
            temp2.append(rating)
    newUserTitles.append(temp1)
    newUserRatings.append(temp2)
    


#this might lead to a referencce error
#populate infos; a list of data frames
infos = []
for user in newUserTitles:
    i = 0
    tempInfo = pd.DataFrame(columns = list(moviesFull.columns))
    for name in user:
        if(len(moviesFull[moviesFull["title"] == name]) !=0):
            tempInfo.loc[i] = moviesFull[moviesFull["title"] == name].iloc[0]
        i+=1
    infos.append(tempInfo)
    

features = ['keywords','cast','genres','director']


for info in infos:
    for feature in features:
        info[feature] = info[feature].fillna('')

colNumbers = []
for feature in features:   
    colNumbers.append(infos[0].columns.get_loc(feature))

fullDataList =[]


for frame in infos:
    fullDataList.append(frame.values.tolist())

combinedFeatures = []

for item in fullDataList:
    tmp = []
    for row in item:
        tmp.append(row[colNumbers[0]]+" "+row[colNumbers[1]]+" "+row[colNumbers[2]]+" "+row[colNumbers[3]])
    combinedFeatures.append(tmp)


def transform1(arr):
    ret = []
    for item in arr:
        if(item<=.5):
            ret.append(1/item)
        if(item>.5):
            ret.append(-1*(1/(1-item)))
    return ret

def transform2(arr):
    ret = []
    for item in arr:
        ret.append(1/item)
    return ret

X = []
y = []

for i in range(len(combinedFeatures)):
    cv = CountVectorizer() 
    count_matrix = cv.fit_transform(combinedFeatures[i]).toarray()
    cosine_sim = cosine_similarity(X = count_matrix[1:count_matrix.shape[1]]
    ,Y = [count_matrix[0]])

    ratings = newUserRatings[i][1:]
    similairities = np.reshape(cosine_sim,  (len(cosine_sim)))

    averageRating =  sum(ratings)/(len(ratings))

    tmp = []
    tmp.append(averageRating)
    tmp.append(sum(similairities)/(len(similairities)))
    tmp.append(statistics.variance(ratings))
    tmp.append(statistics.variance(similairities))
    ratingsZ = stats.zscore(ratings)
    ratingsZ = [0 if math.isnan(x) else x for x in ratingsZ]
    ratingsZ = [-item if item<0 else item for item in ratingsZ]
    simsZ  = stats.zscore(similairities)
    simsZ = [-item if item<0 else item for item in simsZ]

    totalRating = 0

    for sim, rating,simZ, ratingZ in zip(similairities, ratings, simsZ, ratingsZ):
        totalRating += sim*(rating-averageRating)*simZ*ratingZ
    
    tmp.append(totalRating)
    #next try just total rating
    X.append(tmp)
    y.append(newUserRatings[i][0])



#new varriables to feed into the linear reg model:
#variance of ratings, variance of similairities
#mean of ratings, mean of similarities, rating diff

reg = LinearRegression().fit(X, y)
#note: uses training data to test
print("after linear regression:", reg.score(X, y))
predicted = reg.predict(X)
for item, actual in zip(predicted, y):
    print("predicted:", item)
    print("actual:", actual)
# Out:
# after linear regression: 0.240741756905692
# predicted: 4.398479212337374
# actual: 4.0
# predicted: 4.205338753599899
# actual: 3.0
# predicted: 2.041309705324791
# actual: 0.5
# predicted: 3.4416524342298267
# actual: 3.0
# predicted: 3.7624840140102496
# actual: 4.0
# predicted: 3.8397484095111265
# actual: 3.0
# predicted: 3.507742110463193
# actual: 4.5
# predicted: 3.913402805411112
# actual: 2.0
# predicted: 3.534649279119961
# actual: 3.0
# predicted: 3.2970250798253957
# actual: 1.0
# predicted: 3.9662974723075353
# actual: 3.0
# predicted: 4.608920949488333
# actual: 4.0
# predicted: 3.801771984648926
# actual: 3.0
# predicted: 3.343876657374601
# actual: 1.0
# predicted: 3.335412950085434
# actual: 2.5
# predicted: 3.834692869308764
# actual: 4.0
# predicted: 4.243162001706884
# actual: 4.5
# predicted: 3.6157845462922085
# actual: 3.5
# predicted: 3.1277951897747043
# actual: 4.0
# predicted: 3.791055158388771
# actual: 4.0
# predicted: 3.6005459883435322
# actual: 3.5
# predicted: 2.667359230619571
# actual: 5.0
# predicted: 3.69756362829814
# actual: 4.0
# predicted: 3.821160586553899
# actual: 4.0
# predicted: 5.10595568608541
# actual: 5.0
# predicted: 3.525919144825971
# actual: 3.0
# predicted: 3.7033528257916837
# actual: 3.0
# predicted: 3.1938130919371064
# actual: 2.5
# predicted: 4.318288045444932
# actual: 3.5
# predicted: 4.647390483298574
# actual: 5.0
# predicted: 3.9874410189514413
# actual: 5.0
# predicted: 3.729712059825912
# actual: 3.0
# predicted: 3.9443052911517906
# actual: 3.0
# predicted: 3.405415188463589
# actual: 5.0
# predicted: 4.466934653552991
# actual: 4.0
# predicted: 3.0050200290949003
# actual: 2.5
# predicted: 4.094024020677329
# actual: 5.0
# predicted: 3.662579840417722
# actual: 5.0
# predicted: 3.98552171246299
# actual: 5.0
# predicted: 3.8835422470748093
# actual: 5.0
# predicted: 3.394751205164558
# actual: 3.0
# predicted: 3.6658203257386597
# actual: 5.0
# predicted: 4.646396235429716
# actual: 5.0
# predicted: 3.4188664819341255
# actual: 3.0
# predicted: 4.276645934265455
# actual: 4.0
# predicted: 4.112580551876307
# actual: 5.0
# predicted: 3.291536341373067
# actual: 3.0
# predicted: 4.12173936479857
# actual: 4.0
# predicted: 4.3581130254613125
# actual: 4.0
# predicted: 2.763944238786526
# actual: 3.0
# predicted: 3.9112618473437415
# actual: 3.0
# predicted: 4.446656734190533
# actual: 4.0
# predicted: 4.965970119487654
# actual: 5.0
# predicted: 3.2884305087664205
# actual: 3.0
# predicted: 2.9476137303397487
# actual: 0.5
# predicted: 3.9980445730533356
# actual: 4.0
# predicted: 3.2900568582962975
# actual: 5.0
# predicted: 3.7699163564024687
# actual: 1.0
# predicted: 4.157191479138197
# actual: 3.0
# predicted: 3.9513494555599604
# actual: 3.0
# predicted: 4.201612339308044
# actual: 4.0
# predicted: 4.157025740078549
# actual: 4.5
# predicted: 3.704137819167648
# actual: 5.0
# predicted: 3.6809293177134705
# actual: 4.0
# predicted: 4.163789854472289
# actual: 4.0
# predicted: 4.007297616887126
# actual: 4.0
# predicted: 3.9649280347541667
# actual: 4.5
# predicted: 3.148587699300951
# actual: 2.5
# predicted: 4.365090894648696
# actual: 5.0
# predicted: 4.398809613761012
# actual: 5.0
# predicted: 3.883071794569491
# actual: 5.0
# predicted: 4.277515347802423
# actual: 4.5
# predicted: 3.7151725458590747
# actual: 4.5
# predicted: 4.506259122125093
# actual: 5.0
# predicted: 3.2425110126369523
# actual: 2.0
# predicted: 2.49620805842664
# actual: 0.5
# predicted: 3.8899379792990696
# actual: 5.0
# predicted: 3.176595434873971
# actual: 4.0
# predicted: 4.108313961532412
# actual: 5.0
# predicted: 4.514272044362366
# actual: 4.5
# predicted: 3.068408551017778
# actual: 1.0
# predicted: 3.034379529894695
# actual: 2.5
# predicted: 3.611540541957275
# actual: 4.0
# predicted: 3.8236676141099655
# actual: 3.0
# predicted: 3.851035514262976
# actual: 4.0
# predicted: 4.028115896916564
# actual: 4.0
# predicted: 3.8802310180489576
# actual: 3.0
# predicted: 4.361074440205422
# actual: 4.5
# predicted: 3.6003432600861935
# actual: 3.0
# predicted: 4.1885895066193095
# actual: 3.0
# predicted: 3.185482673355271
# actual: 4.0
# predicted: 3.9834871539245698
# actual: 3.5
# predicted: 4.3848491344540435
# actual: 3.0
# predicted: 3.298258839013448
# actual: 3.0
# predicted: 4.090063112266375
# actual: 3.5
# predicted: 3.9442228474493564
# actual: 5.0
# predicted: 4.278298459366194
# actual: 4.0
# predicted: 4.040638298685614
# actual: 4.5
# predicted: 4.114243024062476
# actual: 4.0
# predicted: 4.1216240519625025
# actual: 4.0
# predicted: 3.6570835198878737
# actual: 4.0
# predicted: 3.83832184206635
# actual: 3.0
# predicted: 3.684885431107492
# actual: 4.0
# predicted: 3.514916956552489
# actual: 3.0
# predicted: 4.445443473054718
# actual: 4.5
# predicted: 4.401349278369455
# actual: 5.0
# predicted: 4.004235554947363
# actual: 4.0
# predicted: 4.0817595989071105
# actual: 4.0
# predicted: 3.6487837194350194
# actual: 4.0
# predicted: 3.8774855907767263
# actual: 3.5
# predicted: 3.1807210657072877
# actual: 4.5
# predicted: 3.5064953016066385
# actual: 3.0
# predicted: 3.6266738246989125
# actual: 3.0
# predicted: 3.584804696976746
# actual: 3.0
# predicted: 3.754569110701226
# actual: 4.0
# predicted: 3.7078874462896336
# actual: 1.0
# predicted: 3.544728441775934
# actual: 3.0
# predicted: 4.07715480587321
# actual: 2.0
# predicted: 4.2103019776483945
# actual: 3.5
# predicted: 3.4673345851047634
# actual: 3.0
# predicted: 3.5327757551280516
# actual: 4.0
# predicted: 4.591479884156656
# actual: 3.5
# predicted: 4.1914809450431525
# actual: 4.0
# predicted: 4.089774240873165
# actual: 4.0
# predicted: 3.935483831686594
# actual: 3.0
# predicted: 3.752665275783387
# actual: 3.0
# predicted: 3.3150231939308954
# actual: 4.0
# predicted: 4.05477357779539
# actual: 5.0
# predicted: 4.082053380783386
# actual: 4.0
# predicted: 3.714729895925229
# actual: 3.0
# predicted: 3.632151215220662
# actual: 4.0
# predicted: 2.6426658456215133
# actual: 2.0
# predicted: 3.2823693362460955
# actual: 3.0
# predicted: 3.6964212799236265
# actual: 3.0
# predicted: 3.7632911612414572
# actual: 4.0
# predicted: 3.5806183627939747
# actual: 5.0
# predicted: 3.962966029608093
# actual: 4.0
# predicted: 3.0945639712756146
# actual: 4.5
# predicted: 2.599947080822907
# actual: 1.0
# predicted: 3.3375080482287065
# actual: 3.0
# predicted: 4.092036782449259
# actual: 4.0
# predicted: 3.981154386582162
# actual: 4.0
# predicted: 3.3840132898803663
# actual: 5.0
# predicted: 3.7309441149407387
# actual: 3.5
# predicted: 3.504291859472481
# actual: 5.0
# predicted: 3.4332224057056298
# actual: 2.0
# predicted: 3.645717645485783
# actual: 1.5
# predicted: 3.8730686612566125
# actual: 4.0
# predicted: 3.2028882344751564
# actual: 3.0
# predicted: 3.593508528987451
# actual: 4.0
# predicted: 3.7357775929123047
# actual: 5.0
# predicted: 4.148272596654071
# actual: 4.5
# predicted: 2.4274095947213
# actual: 2.0
# predicted: 4.4998672507932165
# actual: 5.0
# predicted: 3.906051048087615
# actual: 3.0
# predicted: 3.615409366340222
# actual: 4.0
# predicted: 3.5849743178615254
# actual: 5.0
# predicted: 3.7640992063279857
# actual: 3.0
# predicted: 3.9605684302720463
# actual: 4.5
# predicted: 2.8710477613751926
# actual: 4.0
# predicted: 3.9251851616812696
# actual: 4.0
# predicted: 4.359250665432617
# actual: 5.0
# predicted: 3.3749975278819284
# actual: 3.0
# predicted: 4.132827102453783
# actual: 5.0
# predicted: 3.6932747885857555
# actual: 4.0
# predicted: 4.235085336922577
# actual: 5.0
# predicted: 3.579773504550203
# actual: 3.5
# predicted: 4.502785321157372
# actual: 4.5
# predicted: 4.474881089219361
# actual: 4.5
# predicted: 3.6334514557052398
# actual: 3.0
# predicted: 4.5019289910213764
# actual: 5.0
# predicted: 3.839590776825844
# actual: 4.5
# predicted: 3.6252055421361518
# actual: 3.0
# predicted: 3.9315067220879856
# actual: 3.0
# predicted: 4.025706231325656
# actual: 4.0
# predicted: 4.2287680385424675
# actual: 5.0
# predicted: 3.8638910738891385
# actual: 5.0
# predicted: 4.181770561515952
# actual: 4.0
# predicted: 4.042594893306196
# actual: 4.0
# predicted: 3.6465138032991478
# actual: 3.0
# predicted: 3.2666892790274944
# actual: 2.0
# predicted: 3.5288884399197302
# actual: 4.0
# predicted: 4.090856864694047
# actual: 5.0
# predicted: 4.057970056579785
# actual: 3.5
# predicted: 3.8934216575777367
# actual: 4.0
# predicted: 4.231989718618404
# actual: 4.0
# predicted: 3.679316086326651
# actual: 4.0
# predicted: 4.44200047827282
# actual: 5.0
# predicted: 4.231933423470476
# actual: 4.0
# predicted: 3.939868593039309
# actual: 4.0
# predicted: 3.625587272628952
# actual: 4.0
# predicted: 4.27483916068179
# actual: 5.0
# predicted: 3.824230605130393
# actual: 2.0
# predicted: 3.6634409225616853
# actual: 2.0
# predicted: 3.071949720607994
# actual: 4.0
# predicted: 4.040855552381748
# actual: 4.5
# predicted: 3.9014548310422574
# actual: 3.0
# predicted: 3.785199314699017
# actual: 3.0
# predicted: 3.3860153721556303
# actual: 4.0
# predicted: 3.8606435492231768
# actual: 3.5
# predicted: 4.132022695528201
# actual: 5.0
# predicted: 3.8717376207870093
# actual: 4.0
# predicted: 4.194558855581217
# actual: 5.0
# predicted: 4.166762582517883
# actual: 4.5
# predicted: 3.8648734586247584
# actual: 4.0
# predicted: 4.066457988722883
# actual: 5.0
# predicted: 2.9594731750347076
# actual: 3.0
# predicted: 3.6162160899380336
# actual: 2.0
# predicted: 4.327435799554626
# actual: 5.0
# predicted: 4.106546525044596
# actual: 3.5
# predicted: 4.016015408278257
# actual: 4.0
# predicted: 3.766556931163799
# actual: 3.5
# predicted: 4.056028947825014
# actual: 3.5
# predicted: 3.0053607767612527
# actual: 3.0
# predicted: 3.9942233256959065
# actual: 5.0
# predicted: 3.854858039915288
# actual: 3.0
# predicted: 4.081370432410601
# actual: 4.0
# predicted: 3.4904073747157707
# actual: 4.0
# predicted: 2.825334363692714
# actual: 3.5
# predicted: 4.207534008865991
# actual: 5.0
# predicted: 4.140409561007667
# actual: 4.5
# predicted: 3.4087668443620567
# actual: 3.5
# predicted: 3.3184262963454496
# actual: 3.5
# predicted: 4.641031636136984
# actual: 5.0
# predicted: 3.7806933356565158
# actual: 5.0
# predicted: 3.5864792964192427
# actual: 3.5
# predicted: 4.341267486291283
# actual: 3.5
# predicted: 3.9980799729140433
# actual: 4.5
# predicted: 3.8978081106144677
# actual: 5.0
# predicted: 3.0373786074207194
# actual: 2.0
# predicted: 4.077998487379745
# actual: 4.0
# predicted: 3.543220612161559
# actual: 3.5
# predicted: 3.6875390379358266
# actual: 3.0
# predicted: 4.048059005041795
# actual: 5.0
# predicted: 3.7916820902706365
# actual: 2.0
# predicted: 3.8702347570570343
# actual: 5.0
# predicted: 3.644049877358651
# actual: 2.5
# predicted: 3.849391150502993
# actual: 4.0
# predicted: 3.9818294706770097
# actual: 4.0
# predicted: 4.146693694069571
# actual: 5.0
# predicted: 4.081647308178105
# actual: 4.0
# predicted: 3.8915447941559047
# actual: 3.0
# predicted: 4.226493174337186
# actual: 5.0
# predicted: 3.9026022089515178
# actual: 5.0
# predicted: 2.8135574259813847
# actual: 4.0
# predicted: 3.984717043913627
# actual: 5.0
# predicted: 4.013751423324903
# actual: 5.0
# predicted: 4.096963625227845
# actual: 3.5
# predicted: 3.58248435914064
# actual: 4.0
# predicted: 4.219207692424796
# actual: 4.0
# predicted: 4.918070038853526
# actual: 4.5
# predicted: 4.738493880488472
# actual: 4.5
# predicted: 4.102218513689826
# actual: 5.0
# predicted: 4.135707333194551
# actual: 4.5
# predicted: 2.779548435169936
# actual: 1.0
# predicted: 4.003891117331685
# actual: 5.0
# predicted: 3.189283049528466
# actual: 3.5
# predicted: 4.4166031483231
# actual: 5.0
# predicted: 3.301141647953888
# actual: 4.0
# predicted: 3.7828331855556407
# actual: 5.0
# predicted: 4.0594482518440795
# actual: 4.0
# predicted: 3.267321623416913
# actual: 2.0
# predicted: 3.8559646277082082
# actual: 4.0
# predicted: 3.7675924929524456
# actual: 4.0
# predicted: 3.5403264451572403
# actual: 1.0
# predicted: 3.626419584638101
# actual: 2.0
# predicted: 4.0632042970764894
# actual: 4.0
# predicted: 3.483658029382909
# actual: 4.0
# predicted: 3.739266445082629
# actual: 5.0
# predicted: 3.278934274550129
# actual: 5.0
# predicted: 3.379804409764267
# actual: 4.0
# predicted: 3.7196318339663543
# actual: 4.0
# predicted: 4.127901515829538
# actual: 5.0
# predicted: 3.4615036583035543
# actual: 4.0
# predicted: 4.031252915343146
# actual: 5.0
# predicted: 4.915483725336945
# actual: 4.0
# predicted: 3.7871887100973214
# actual: 4.0
# predicted: 4.371277059484685
# actual: 5.0
# predicted: 3.3583911175157057
# actual: 3.0
# predicted: 4.0059892349104445
# actual: 4.5
# predicted: 3.472535139716624
# actual: 2.0
# predicted: 4.146719184337869
# actual: 4.5
# predicted: 3.62615900481938
# actual: 3.0
# predicted: 3.59753320155769
# actual: 4.0
# predicted: 3.9792179492836337
# actual: 5.0
# predicted: 3.6649482327984857
# actual: 3.5
# predicted: 2.9432960808874378
# actual: 2.0
# predicted: 3.811171978365901
# actual: 4.5
# predicted: 3.594674412452116
# actual: 4.5
# predicted: 4.059456541846938
# actual: 4.0
# predicted: 4.0291920721019405
# actual: 4.0
# predicted: 3.6969092946696294
# actual: 4.0
# predicted: 2.925738664379576
# actual: 3.0
# predicted: 2.9342096550410197
# actual: 3.0
# predicted: 3.887888395795846
# actual: 3.5
# predicted: 3.877436913185145
# actual: 5.0
# predicted: 2.818006725283295
# actual: 2.0
# predicted: 1.8686924660991906
# actual: 2.0
# predicted: 3.773885763457813
# actual: 2.0
# predicted: 4.288271885765016
# actual: 4.0
# predicted: 3.3080054322995665
# actual: 4.0
# predicted: 3.9737673625169916
# actual: 4.0
# predicted: 4.004372958205554
# actual: 2.5
# predicted: 4.07648862896497
# actual: 5.0
# predicted: 4.499710084679131
# actual: 4.5
# predicted: 3.3368519546404007
# actual: 2.0
# predicted: 3.095124875660271
# actual: 4.0
# predicted: 2.7434139275897262
# actual: 1.0
# predicted: 3.8594128464328494
# actual: 4.5
# predicted: 3.7554334375938407
# actual: 1.0
# predicted: 2.522477936772022
# actual: 2.5
# predicted: 4.168183011037708
# actual: 4.0
# predicted: 3.6093253586774345
# actual: 4.0
# predicted: 3.299961703846307
# actual: 3.0
# predicted: 3.779235540210295
# actual: 4.0
# predicted: 3.2166916321236245
# actual: 4.5
# predicted: 4.14490021642418
# actual: 5.0
# predicted: 3.85356018655668
# actual: 3.0
# predicted: 4.467794463547602
# actual: 4.5
# predicted: 4.011706620576012
# actual: 4.0
# predicted: 3.8519276089629177
# actual: 3.0
# predicted: 3.3284279326824207
# actual: 3.5
# predicted: 3.438973433729305
# actual: 3.5
# predicted: 3.3396540307145792
# actual: 4.0
# predicted: 3.601359964784415
# actual: 2.0
# predicted: 3.9174708226928123
# actual: 3.5
# predicted: 4.265266756401695
# actual: 4.5
# predicted: 3.717399321320037
# actual: 5.0
# predicted: 2.780460744243089
# actual: 2.0
# predicted: 3.0667100986935965
# actual: 4.0
# predicted: 3.5025280479888736
# actual: 3.0
# predicted: 3.75422040263175
# actual: 4.0
# predicted: 2.5793422865043483
# actual: 3.0
# predicted: 3.6699858259756932
# actual: 3.5
# predicted: 3.7299644574169486
# actual: 5.0
# predicted: 4.383551094045524
# actual: 4.0
# predicted: 4.200625604757426
# actual: 4.0
# predicted: 3.9999815043613944
# actual: 4.5
# predicted: 4.066567266108597
# actual: 4.0
# predicted: 4.315786208328676
# actual: 4.0
# predicted: 3.983160899683943
# actual: 5.0
# predicted: 3.2154381054690218
# actual: 5.0
# predicted: 4.211749677423612
# actual: 4.5
# predicted: 3.5047411266090194
# actual: 4.5
# predicted: 4.153992649191395
# actual: 2.5
# predicted: 3.732998473849362
# actual: 4.0
# predicted: 3.7302121409782
# actual: 5.0
# predicted: 4.679071851694979
# actual: 5.0
# predicted: 4.030059508025197
# actual: 4.0
# predicted: 3.4060007834166184
# actual: 4.0
# predicted: 3.8469471904798405
# actual: 4.5
# predicted: 3.958704092325438
# actual: 5.0
# predicted: 3.58089739404219
# actual: 5.0
# predicted: 3.6980014296720842
# actual: 3.5
# predicted: 3.860432051899541
# actual: 3.0
# predicted: 4.087318801895734
# actual: 3.5
# predicted: 4.334476908948286
# actual: 5.0
# predicted: 3.804476925695411
# actual: 5.0
# predicted: 3.6948921894107136
# actual: 4.0
# predicted: 3.8020272860668283
# actual: 4.0
# predicted: 3.443545342293845
# actual: 3.5
# predicted: 4.503526995220845
# actual: 4.0
# predicted: 3.584434444355218
# actual: 4.0
# predicted: 4.311229315298935
# actual: 5.0
# predicted: 2.832670752039558
# actual: 3.5
# predicted: 4.081229239797434
# actual: 4.0
# predicted: 4.09083398176601
# actual: 5.0
# predicted: 2.9770526800528683
# actual: 3.0
# predicted: 3.712999988146056
# actual: 4.0
# predicted: 3.734254236834416
# actual: 3.5
# predicted: 4.5660078873526935
# actual: 4.5
# predicted: 3.4417678625306922
# actual: 3.0
# predicted: 3.2687445450542922
# actual: 3.0
# predicted: 3.673921930196477
# actual: 5.0
# predicted: 3.8721640047212853
# actual: 5.0
# predicted: 4.181516637719364
# actual: 4.5
# predicted: 3.995908197698677
# actual: 2.0
# predicted: 4.2275210952853275
# actual: 4.5
# predicted: 3.529590633500504
# actual: 2.0
# predicted: 4.605631933109892
# actual: 5.0
# predicted: 3.515488216581353
# actual: 3.5
# predicted: 3.4096176734197754
# actual: 4.5
# predicted: 3.767437315721109
# actual: 4.0
# predicted: 3.445026368317989
# actual: 4.0
# predicted: 3.551115022773468
# actual: 4.0
# predicted: 2.9120969617075216
# actual: 3.0
# predicted: 3.1660859920613484
# actual: 3.5
# predicted: 4.124574081155936
# actual: 4.0
# predicted: 3.9633062160587205
# actual: 5.0
# predicted: 3.8568341619261055
# actual: 4.0
# predicted: 3.6094324676347584
# actual: 3.0
# predicted: 3.5678089468854925
# actual: 3.0
# predicted: 3.5631084077090383
# actual: 4.0
# predicted: 3.286136122423107
# actual: 3.0
# predicted: 3.4499959797822615
# actual: 3.0
# predicted: 3.459106223766519
# actual: 5.0
# predicted: 5.039333887895269
# actual: 4.0
# predicted: 4.344056825114966
# actual: 3.5
# predicted: 4.0602518230196605
# actual: 4.0
# predicted: 4.495639471775906
# actual: 5.0
# predicted: 3.878962956155146
# actual: 3.5
# predicted: 4.087630201268467
# actual: 3.0
# predicted: 3.831841926850098
# actual: 5.0
# predicted: 3.6828766756673317
# actual: 4.0
# predicted: 4.181842863338667
# actual: 4.0
# predicted: 3.5060889590635425
# actual: 4.0
# predicted: 4.419349055487558
# actual: 3.0
# predicted: 4.261596355356238
# actual: 4.5
# predicted: 3.8361158011237966
# actual: 4.0
# predicted: 3.972390721271764
# actual: 3.0
# predicted: 3.5715591068922214
# actual: 5.0
# predicted: 3.733387783660133
# actual: 2.0
# predicted: 4.463581783932244
# actual: 5.0
# predicted: 4.0296688505526355
# actual: 4.0
# predicted: 4.218034225054244
# actual: 4.5
# predicted: 3.107433908945531
# actual: 2.5
# predicted: 4.4790818802306305
# actual: 5.0
# predicted: 3.673276765678657
# actual: 4.5
# predicted: 3.7973594748557025
# actual: 3.5
# predicted: 3.8680059901774246
# actual: 4.0
# predicted: 4.254978262302524
# actual: 4.0
# predicted: 3.374960503390542
# actual: 4.0
# predicted: 3.720351081367
# actual: 3.0
# predicted: 3.866774336866532
# actual: 5.0
# predicted: 3.6835273454800657
# actual: 3.0
# predicted: 3.6460709209495956
# actual: 3.5
# predicted: 3.512275456131437
# actual: 4.0
# predicted: 2.754844195008011
# actual: 1.0
# predicted: 4.184840656370547
# actual: 4.0
# predicted: 3.8985218193916227
# actual: 3.0
# predicted: 3.0777175079117916
# actual: 1.0
# predicted: 3.0320395366296062
# actual: 2.5
# predicted: 3.9949097266459965
# actual: 5.0
# predicted: 3.653017860079198
# actual: 4.0
# predicted: 4.403751796722495
# actual: 4.0
# predicted: 3.512355555901368
# actual: 4.0
# predicted: 3.923983189397847
# actual: 3.0
# predicted: 3.9088352666050614
# actual: 4.5
# predicted: 4.225888724625797
# actual: 3.5
# predicted: 3.9528801435747183
# actual: 3.5
# predicted: 4.5231775293778895
# actual: 4.5
# predicted: 1.5777649727444936
# actual: 2.5
# predicted: 4.083515408638226
# actual: 4.0
# predicted: 4.195825055889825
# actual: 4.0
# predicted: 3.9220022112577158
# actual: 3.5
# predicted: 3.4517167139195544
# actual: 3.0
# predicted: 4.0027323371844
# actual: 3.0
# predicted: 5.16963520494359
# actual: 5.0
# predicted: 3.4997188536455157
# actual: 4.5
# predicted: 4.24278667485782
# actual: 2.0
# predicted: 3.5807866175911416
# actual: 5.0
# predicted: 4.34887644547058
# actual: 4.0
# predicted: 4.419039916761639
# actual: 5.0
# predicted: 4.107065003277945
# actual: 3.0
# predicted: 3.7936149098720797
# actual: 4.0
# predicted: 3.984097612815816
# actual: 5.0
# predicted: 3.591329155069732
# actual: 2.0
# predicted: 4.275732255799724
# actual: 4.0
# predicted: 4.267727212469012
# actual: 4.0
# predicted: 4.35636299838171
# actual: 4.5
# predicted: 3.0328575303115675
# actual: 4.5
# predicted: 2.9069271709773274
# actual: 1.5
# predicted: 4.037925015980645
# actual: 4.5
# predicted: 4.031135365842419
# actual: 4.5
# predicted: 3.956305045395056
# actual: 3.0
# predicted: 3.988497582124163
# actual: 3.0
# predicted: 3.5779238253239747
# actual: 4.0
# predicted: 3.5451482834835786
# actual: 4.0
# predicted: 3.712126960818131
# actual: 4.0
# predicted: 3.7810184378995393
# actual: 4.0
# predicted: 4.109582817614598
# actual: 5.0
# predicted: 4.265351904722182
# actual: 5.0
# predicted: 3.5962824167901353
# actual: 2.0
# predicted: 2.3687831537283253
# actual: 4.0
# predicted: 4.47962126663942
# actual: 4.0
# predicted: 3.950336281530665
# actual: 4.0
# predicted: 2.449755064312428
# actual: 4.0
# predicted: 3.106712936354248
# actual: 2.0
# predicted: 3.514584022357441
# actual: 3.0
# predicted: 3.1964742056051616
# actual: 3.0
# predicted: 2.9687476301027513
# actual: 4.0
# predicted: 3.615163665249405
# actual: 2.0
# predicted: 3.7143142318956537
# actual: 4.0
# predicted: 4.045057227507937
# actual: 4.5
# predicted: 4.425871179741432
# actual: 4.0
# predicted: 4.2811822974795435
# actual: 4.0
# predicted: 3.417687365361237
# actual: 3.0
# predicted: 4.043586780563712
# actual: 4.5
# predicted: 2.2273631384693813
# actual: 2.5
# predicted: 3.42915080000457
# actual: 3.5
# predicted: 4.329299927229758
# actual: 2.5
# predicted: 4.166076412210309
# actual: 4.0
# predicted: 3.563834840367898
# actual: 5.0
# predicted: 4.2439062526291345
# actual: 5.0
# predicted: 3.865309785929624
# actual: 4.5
# predicted: 3.7261469247896803
# actual: 5.0
# predicted: 3.7124994338785897
# actual: 4.0
# predicted: 4.134966482136596
# actual: 3.0
# predicted: 3.8672212349412676
# actual: 0.5
# predicted: 3.9568057099100846
# actual: 4.0
# predicted: 3.2908998822656494
# actual: 4.0
# predicted: 3.5888399071828845
# actual: 3.5
# predicted: 3.4761463682560176
# actual: 4.5
# predicted: 3.948024685622283
# actual: 4.0
# predicted: 4.282923224235592
# actual: 2.5
# predicted: 3.4699612359321423
# actual: 5.0
# predicted: 3.5088582416018133
# actual: 5.0
# predicted: 2.769331172213148
# actual: 2.5
# predicted: 3.358123780349647
# actual: 4.0
# predicted: 3.1332964087191217
# actual: 1.0
# predicted: 4.168194140244621
# actual: 5.0
# predicted: 3.802258945862091
# actual: 4.0
# predicted: 4.081508930390422
# actual: 4.0
# predicted: 3.7158425802542445
# actual: 4.0
# predicted: 5.052765104147389
# actual: 4.5
# predicted: 3.90446413706217
# actual: 4.0
# predicted: 2.9575894330052197
# actual: 4.0
# predicted: 3.67655448641962
# actual: 3.0
# predicted: 4.51478616973022
# actual: 5.0
# predicted: 3.8781955071045595
# actual: 4.0
# predicted: 3.7402136296490975
# actual: 4.0
# predicted: 3.5301228282948047
# actual: 3.0
# predicted: 4.741800583784497
# actual: 4.0
# predicted: 3.721683113961262
# actual: 4.0
# predicted: 3.539407478210132
# actual: 4.0
# predicted: 4.255680359033184
# actual: 5.0
# predicted: 4.336962872673025
# actual: 5.0
# predicted: 3.5220644430787473
# actual: 2.5
# predicted: 3.2128163575781508
# actual: 3.0
# predicted: 3.9009390273432687
# actual: 4.0
# predicted: 4.135078118602868
# actual: 4.0
# predicted: 4.378730798008041
# actual: 5.0
# predicted: 4.450262103362395
# actual: 5.0
# predicted: 4.087144413138592
# actual: 4.0
# predicted: 2.8496205779569466
# actual: 2.0
# predicted: 3.551433712928147
# actual: 5.0
# predicted: 4.194723075094492
# actual: 4.0
# predicted: 4.509789421094663
# actual: 4.5
# predicted: 4.067436761112048
# actual: 4.0
# predicted: 4.293142497180907
# actual: 3.5
# predicted: 3.5472007543679696
# actual: 3.0
# predicted: 3.3645714757239893
# actual: 3.5
# predicted: 4.410888426190747
# actual: 5.0
# predicted: 4.618616215358137
# actual: 3.0
# predicted: 3.657674261585656
# actual: 2.5
# predicted: 3.3474799786202665
# actual: 5.0
# predicted: 4.067361433386054
# actual: 5.0
# predicted: 4.404688150215779
# actual: 5.0
# predicted: 3.90015938770258
# actual: 3.0
# predicted: 4.359619596356793
# actual: 4.0
# predicted: 3.8290370550698714
# actual: 3.5
# predicted: 2.99932441434679
# actual: 3.5
# predicted: 4.584295663782486
# actual: 5.0
# predicted: 4.124398555067232
# actual: 5.0
# predicted: 3.877325508459361
# actual: 4.0
# predicted: 4.4589229143303015
# actual: 5.0
# predicted: 4.186204986054188
# actual: 4.5
# predicted: 3.2368166287266695
# actual: 4.0
# predicted: 3.506496603651339
# actual: 5.0
# predicted: 3.486107678098616
# actual: 3.0
# predicted: 3.5726938043404712
# actual: 4.0
# predicted: 4.289281820382394
# actual: 4.5
# predicted: 3.0700927161634
# actual: 2.0
# predicted: 3.876668425271205
# actual: 3.5
# predicted: 3.801498371949663
# actual: 3.0
# predicted: 3.6033943331237794
# actual: 3.0
# predicted: 2.8292310221529133
# actual: 3.5
# predicted: 4.181575683934733
# actual: 5.0
# predicted: 4.2415856043385505
# actual: 4.0
# predicted: 3.5080817881889423
# actual: 4.0
# predicted: 3.6730119963747807
# actual: 2.0
# predicted: 4.107118170614221
# actual: 4.0
# predicted: 4.337919551492997
# actual: 5.0
# predicted: 3.9864237403976364
# actual: 5.0
# predicted: 3.0623989545961274
# actual: 5.0
# predicted: 3.6098853005879423
# actual: 2.5
# predicted: 3.8083474721594714
# actual: 3.0
# predicted: 4.418417524898427
# actual: 4.0
# predicted: 4.3346147913893205
# actual: 4.0
# predicted: 3.5604881295830375
# actual: 3.0
# predicted: 4.425275123382583
# actual: 5.0
# predicted: 4.071306894325446
# actual: 4.0
# predicted: 3.6124222499371763
# actual: 5.0
# predicted: 4.14764920210721
# actual: 5.0
# predicted: 4.580850893201405
# actual: 5.0
# predicted: 4.129474131273127
# actual: 5.0
# predicted: 3.701042297621543
# actual: 5.0
# predicted: 3.3961086926269104
# actual: 3.0
# predicted: 4.309798588801549
# actual: 5.0
# predicted: 3.372707229055036
# actual: 4.0
# predicted: 3.2511109943596184
# actual: 4.0
# predicted: 3.9699546253568907
# actual: 3.0
# predicted: 3.3821399847740663
# actual: 4.0
# predicted: 4.326540111501245
# actual: 5.0
# predicted: 4.165433587141472
# actual: 5.0
# predicted: 3.7203965468352607
# actual: 4.0
# predicted: 3.9327665695466556
# actual: 4.0
# predicted: 3.816625695285137
# actual: 0.5
# predicted: 2.458135253396856
# actual: 3.0
# predicted: 2.8821091789665663
# actual: 2.5
# predicted: 4.308109296241684
# actual: 4.0
# predicted: 3.7060944958520814
# actual: 3.0
# predicted: 3.2485513265528088
# actual: 4.0
# predicted: 3.583305858302673
# actual: 3.0
# predicted: 3.502712667974427
# actual: 4.0
# predicted: 3.4427562077311338
# actual: 2.5
# predicted: 3.792344787370526
# actual: 4.0
# predicted: 2.211255399435103
# actual: 2.5
# predicted: 3.48095736376193
# actual: 3.0
# predicted: 4.489478063013422
# actual: 5.0
