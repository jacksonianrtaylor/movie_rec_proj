# %%
import pandas as pd
from scipy import sparse
import pandas as pd
import numpy as np
from numpy import var
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random
from matplotlib import pyplot as plt
from scipy.stats import norm
import numpy as np
from fitter import Fitter, get_common_distributions, get_distributions
from scipy import stats
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statistics
import math

#load data
ratings = pd.read_csv('dataset/ratings.csv')
moviesPartial = pd.read_csv('dataset/movies.csv')
moviesFull = pd.read_csv('dataset/movie_dataset.csv')

#drop duplicates
moviesFull.drop_duplicates(subset = 'title', inplace=True)

#drop columns that do nothing
ratings = ratings.drop(['timestamp'], axis = 1)
moviesPartial = moviesPartial.drop(['genres'],axis=1)

#all the users are to be tested
userRatings = []
for i in range(1,611):
    userRatings.append(ratings[ratings['userId'] ==i])

#remove the year and keep the name
moviesPartial['title'] = moviesPartial['title'].map(lambda string: string[:-7])

#drop duplicates
moviesPartial.drop_duplicates(subset = 'title', inplace=True)

#helper functions:
def get_title_from_movieId(tmp):
    return moviesPartial[moviesPartial["movieId"]== tmp]["title"].to_string(index=False)

def checkTitle(tmp):
    if(tmp not in list(moviesFull["title"])):
        #The word "the" is being apended to the ends of titles
        tmp = tmp[-3:] +" "+ tmp[:-5]
        return moviesFull[moviesFull["title"] == tmp]["title"].to_string(index=False)
    else:
        return moviesFull[moviesFull["title"] == tmp]["title"].to_string(index=False)



#used to filter out movies that are not in both data sets
newUserTitles = []
newUserRatings = []
for userRating in userRatings:
    temp1 = []
    temp2 = []
    for rating, id in zip(list(userRating["rating"]), list(userRating["movieId"])):
        title = get_title_from_movieId(id)
        checked = checkTitle(title)
        if(checked != 'Series([], )'):
            temp1.append(checked)
            temp2.append(rating)
    newUserTitles.append(temp1)
    newUserRatings.append(temp2)
    


#this might lead to a referencce error
#populate infos; a list of data frames
infos = []
for user in newUserTitles:
    i = 0
    tempInfo = pd.DataFrame(columns = list(moviesFull.columns))
    for name in user:
        if(len(moviesFull[moviesFull["title"] == name]) !=0):
            tempInfo.loc[i] = moviesFull[moviesFull["title"] == name].iloc[0]
        i+=1
    infos.append(tempInfo)
    

features = ['keywords','cast','genres','director']


for info in infos:
    for feature in features:
        info[feature] = info[feature].fillna('')

colNumbers = []
for feature in features:   
    colNumbers.append(infos[0].columns.get_loc(feature))

fullDataList =[]


for frame in infos:
    fullDataList.append(frame.values.tolist())

combinedFeatures = []

for item in fullDataList:
    tmp = []
    for row in item:
        tmp.append(row[colNumbers[0]]+" "+row[colNumbers[1]]+" "+row[colNumbers[2]]+" "+row[colNumbers[3]])
    combinedFeatures.append(tmp)


def transform1(arr):
    ret = []
    for item in arr:
        if(item<=.5):
            ret.append(1/item)
        if(item>.5):
            ret.append(-1*(1/(1-item)))
    return ret

def transform2(arr):
    ret = []
    for item in arr:
        ret.append(1/item)
    return ret

X = []
y = []

for i in range(len(combinedFeatures)):
    cv = CountVectorizer() 
    count_matrix = cv.fit_transform(combinedFeatures[i]).toarray()
    cosine_sim = cosine_similarity(X = count_matrix[1:count_matrix.shape[1]]
    ,Y = [count_matrix[0]])

    ratings = newUserRatings[i][1:]
    similairities = np.reshape(cosine_sim,  (len(cosine_sim)))

    averageRating =  sum(ratings)/(len(ratings))

    tmp = []
    tmp.append(averageRating)
    tmp.append(sum(similairities)/(len(similairities)))
    tmp.append(statistics.variance(ratings))
    tmp.append(statistics.variance(similairities))
    ratingsZ = stats.zscore(ratings)
    ratingsZ = [0 if math.isnan(x) else x for x in ratingsZ]
    ratingsZ = [-item if item<0 else item for item in ratingsZ]
    simsZ  = stats.zscore(similairities)
    simsZ = [-item if item<0 else item for item in simsZ]

    totalRating = 0

    #does adding constant multiplier help?
    #nots: 20
    for sim, rating,simZ, ratingZ in zip(similairities, ratings, simsZ, ratingsZ):
        totalRating += sim*(rating-averageRating)*simZ*ratingZ
    
    tmp.append(totalRating)
    #next try just total rating
    X.append(tmp)
    y.append(newUserRatings[i][0])



#new varriables to feed into the linear reg model:
#variance of ratings, variance of similairities
#mean of ratings, mean of similarities, rating diff

reg = LinearRegression().fit(X, y)
#note: uses training data to test
print("after linear regression:", reg.score(X, y))
predicted = reg.predict(X)
for item, actual in zip(predicted, y):
    print("predicted:", item)
    print("actual:", actual)
# Out:
# after linear regression: 0.240741756905692
# predicted: 4.398479212337375
# actual: 4.0
# predicted: 4.2053387535999
# actual: 3.0
# predicted: 2.041309705324788
# actual: 0.5
# predicted: 3.4416524342298227
# actual: 3.0
# predicted: 3.762484014010252
# actual: 4.0
# predicted: 3.8397484095111296
# actual: 3.0
# predicted: 3.5077421104632003
# actual: 4.5
# predicted: 3.913402805411114
# actual: 2.0
# predicted: 3.5346492791199617
# actual: 3.0
# predicted: 3.297025079825395
# actual: 1.0
# predicted: 3.9662974723075357
# actual: 3.0
# predicted: 4.608920949488336
# actual: 4.0
# predicted: 3.8017719846489264
# actual: 3.0
# predicted: 3.3438766573745946
# actual: 1.0
# predicted: 3.3354129500854266
# actual: 2.5
# predicted: 3.834692869308765
# actual: 4.0
# predicted: 4.243162001706885
# actual: 4.5
# predicted: 3.615784546292203
# actual: 3.5
# predicted: 3.12779518977471
# actual: 4.0
# predicted: 3.7910551583887764
# actual: 4.0
# predicted: 3.6005459883435322
# actual: 3.5
# predicted: 2.6673592306195686
# actual: 5.0
# predicted: 3.697563628298141
# actual: 4.0
# predicted: 3.8211605865539013
# actual: 4.0
# predicted: 5.105955686085409
# actual: 5.0
# predicted: 3.525919144825972
# actual: 3.0
# predicted: 3.7033528257916823
# actual: 3.0
# predicted: 3.1938130919371037
# actual: 2.5
# predicted: 4.318288045444934
# actual: 3.5
# predicted: 4.647390483298574
# actual: 5.0
# predicted: 3.987441018951442
# actual: 5.0
# predicted: 3.729712059825911
# actual: 3.0
# predicted: 3.9443052911517906
# actual: 3.0
# predicted: 3.405415188463592
# actual: 5.0
# predicted: 4.4669346535529915
# actual: 4.0
# predicted: 3.0050200290949065
# actual: 2.5
# predicted: 4.0940240206773275
# actual: 5.0
# predicted: 3.6625798404177283
# actual: 5.0
# predicted: 3.9855217124629894
# actual: 5.0
# predicted: 3.8835422470748084
# actual: 5.0
# predicted: 3.394751205164558
# actual: 3.0
# predicted: 3.665820325738657
# actual: 5.0
# predicted: 4.646396235429718
# actual: 5.0
# predicted: 3.4188664819341255
# actual: 3.0
# predicted: 4.27664593426546
# actual: 4.0
# predicted: 4.112580551876308
# actual: 5.0
# predicted: 3.2915363413730674
# actual: 3.0
# predicted: 4.12173936479857
# actual: 4.0
# predicted: 4.358113025461315
# actual: 4.0
# predicted: 2.7639442387865185
# actual: 3.0
# predicted: 3.911261847343743
# actual: 3.0
# predicted: 4.446656734190531
# actual: 4.0
# predicted: 4.965970119487654
# actual: 5.0
# predicted: 3.2884305087664205
# actual: 3.0
# predicted: 2.947613730339748
# actual: 0.5
# predicted: 3.998044573053335
# actual: 4.0
# predicted: 3.290056858296292
# actual: 5.0
# predicted: 3.7699163564024656
# actual: 1.0
# predicted: 4.157191479138193
# actual: 3.0
# predicted: 3.951349455559962
# actual: 3.0
# predicted: 4.201612339308046
# actual: 4.0
# predicted: 4.15702574007855
# actual: 4.5
# predicted: 3.7041378191676504
# actual: 5.0
# predicted: 3.680929317713465
# actual: 4.0
# predicted: 4.16378985447229
# actual: 4.0
# predicted: 4.007297616887121
# actual: 4.0
# predicted: 3.9649280347541684
# actual: 4.5
# predicted: 3.148587699300944
# actual: 2.5
# predicted: 4.365090894648697
# actual: 5.0
# predicted: 4.398809613761014
# actual: 5.0
# predicted: 3.8830717945694926
# actual: 5.0
# predicted: 4.277515347802424
# actual: 4.5
# predicted: 3.7151725458590694
# actual: 4.5
# predicted: 4.506259122125099
# actual: 5.0
# predicted: 3.2425110126369487
# actual: 2.0
# predicted: 2.496208058426615
# actual: 0.5
# predicted: 3.8899379792990696
# actual: 5.0
# predicted: 3.1765954348739687
# actual: 4.0
# predicted: 4.108313961532412
# actual: 5.0
# predicted: 4.514272044362372
# actual: 4.5
# predicted: 3.0684085510177805
# actual: 1.0
# predicted: 3.0343795298946805
# actual: 2.5
# predicted: 3.6115405419572757
# actual: 4.0
# predicted: 3.823667614109965
# actual: 3.0
# predicted: 3.8510355142629766
# actual: 4.0
# predicted: 4.028115896916564
# actual: 4.0
# predicted: 3.8802310180489585
# actual: 3.0
# predicted: 4.361074440205423
# actual: 4.5
# predicted: 3.600343260086203
# actual: 3.0
# predicted: 4.18858950661931
# actual: 3.0
# predicted: 3.185482673355261
# actual: 4.0
# predicted: 3.9834871539245706
# actual: 3.5
# predicted: 4.3848491344540435
# actual: 3.0
# predicted: 3.298258839013448
# actual: 3.0
# predicted: 4.090063112266376
# actual: 3.5
# predicted: 3.9442228474493577
# actual: 5.0
# predicted: 4.278298459366195
# actual: 4.0
# predicted: 4.040638298685613
# actual: 4.5
# predicted: 4.1142430240624766
# actual: 4.0
# predicted: 4.121624051962504
# actual: 4.0
# predicted: 3.6570835198878733
# actual: 4.0
# predicted: 3.838321842066356
# actual: 3.0
# predicted: 3.6848854311074812
# actual: 4.0
# predicted: 3.5149169565524856
# actual: 3.0
# predicted: 4.445443473054731
# actual: 4.5
# predicted: 4.401349278369455
# actual: 5.0
# predicted: 4.004235554947364
# actual: 4.0
# predicted: 4.0817595989071105
# actual: 4.0
# predicted: 3.6487837194350234
# actual: 4.0
# predicted: 3.877485590776727
# actual: 3.5
# predicted: 3.1807210657072815
# actual: 4.5
# predicted: 3.506495301606637
# actual: 3.0
# predicted: 3.626673824698914
# actual: 3.0
# predicted: 3.584804696976747
# actual: 3.0
# predicted: 3.7545691107012233
# actual: 4.0
# predicted: 3.7078874462896345
# actual: 1.0
# predicted: 3.544728441775935
# actual: 3.0
# predicted: 4.077154805873214
# actual: 2.0
# predicted: 4.210301977648394
# actual: 3.5
# predicted: 3.4673345851047634
# actual: 3.0
# predicted: 3.5327757551280516
# actual: 4.0
# predicted: 4.591479884156659
# actual: 3.5
# predicted: 4.191480945043153
# actual: 4.0
# predicted: 4.089774240873167
# actual: 4.0
# predicted: 3.935483831686594
# actual: 3.0
# predicted: 3.7526652757833885
# actual: 3.0
# predicted: 3.3150231939308963
# actual: 4.0
# predicted: 4.054773577795391
# actual: 5.0
# predicted: 4.082053380783391
# actual: 4.0
# predicted: 3.7147298959252284
# actual: 3.0
# predicted: 3.6321512152206643
# actual: 4.0
# predicted: 2.642665845621493
# actual: 2.0
# predicted: 3.2823693362460955
# actual: 3.0
# predicted: 3.696421279923626
# actual: 3.0
# predicted: 3.763291161241457
# actual: 4.0
# predicted: 3.580618362793978
# actual: 5.0
# predicted: 3.962966029608091
# actual: 4.0
# predicted: 3.0945639712756154
# actual: 4.5
# predicted: 2.5999470808229095
# actual: 1.0
# predicted: 3.3375080482286976
# actual: 3.0
# predicted: 4.09203678244927
# actual: 4.0
# predicted: 3.9811543865821633
# actual: 4.0
# predicted: 3.3840132898803654
# actual: 5.0
# predicted: 3.7309441149407374
# actual: 3.5
# predicted: 3.504291859472481
# actual: 5.0
# predicted: 3.4332224057056315
# actual: 2.0
# predicted: 3.6457176454857816
# actual: 1.5
# predicted: 3.8730686612566143
# actual: 4.0
# predicted: 3.202888234475159
# actual: 3.0
# predicted: 3.593508528987452
# actual: 4.0
# predicted: 3.735777592912305
# actual: 5.0
# predicted: 4.148272596654074
# actual: 4.5
# predicted: 2.4274095947212975
# actual: 2.0
# predicted: 4.499867250793217
# actual: 5.0
# predicted: 3.9060510480876127
# actual: 3.0
# predicted: 3.615409366340218
# actual: 4.0
# predicted: 3.584974317861526
# actual: 5.0
# predicted: 3.764099206327986
# actual: 3.0
# predicted: 3.960568430272059
# actual: 4.5
# predicted: 2.8710477613751926
# actual: 4.0
# predicted: 3.925185161681271
# actual: 4.0
# predicted: 4.359250665432619
# actual: 5.0
# predicted: 3.374997527881926
# actual: 3.0
# predicted: 4.132827102453785
# actual: 5.0
# predicted: 3.693274788585756
# actual: 4.0
# predicted: 4.23508533692258
# actual: 5.0
# predicted: 3.5797735045502006
# actual: 3.5
# predicted: 4.502785321157376
# actual: 4.5
# predicted: 4.474881089219364
# actual: 4.5
# predicted: 3.6334514557052406
# actual: 3.0
# predicted: 4.501928991021375
# actual: 5.0
# predicted: 3.8395907768258417
# actual: 4.5
# predicted: 3.6252055421361526
# actual: 3.0
# predicted: 3.93150672208799
# actual: 3.0
# predicted: 4.025706231325657
# actual: 4.0
# predicted: 4.228768038542469
# actual: 5.0
# predicted: 3.8638910738891483
# actual: 5.0
# predicted: 4.181770561515951
# actual: 4.0
# predicted: 4.042594893306199
# actual: 4.0
# predicted: 3.6465138032991486
# actual: 3.0
# predicted: 3.2666892790274953
# actual: 2.0
# predicted: 3.528888439919731
# actual: 4.0
# predicted: 4.090856864694048
# actual: 5.0
# predicted: 4.057970056579774
# actual: 3.5
# predicted: 3.893421657577734
# actual: 4.0
# predicted: 4.231989718618407
# actual: 4.0
# predicted: 3.6793160863266516
# actual: 4.0
# predicted: 4.4420004782728215
# actual: 5.0
# predicted: 4.231933423470478
# actual: 4.0
# predicted: 3.93986859303931
# actual: 4.0
# predicted: 3.625587272628952
# actual: 4.0
# predicted: 4.274839160681792
# actual: 5.0
# predicted: 3.8242306051303925
# actual: 2.0
# predicted: 3.6634409225616857
# actual: 2.0
# predicted: 3.071949720607974
# actual: 4.0
# predicted: 4.04085555238175
# actual: 4.5
# predicted: 3.901454831042256
# actual: 3.0
# predicted: 3.785199314699023
# actual: 3.0
# predicted: 3.3860153721556228
# actual: 4.0
# predicted: 3.8606435492231754
# actual: 3.5
# predicted: 4.132022695528203
# actual: 5.0
# predicted: 3.8717376207870076
# actual: 4.0
# predicted: 4.194558855581219
# actual: 5.0
# predicted: 4.166762582517884
# actual: 4.5
# predicted: 3.864873458624758
# actual: 4.0
# predicted: 4.0664579887228856
# actual: 5.0
# predicted: 2.959473175034707
# actual: 3.0
# predicted: 3.616216089938033
# actual: 2.0
# predicted: 4.327435799554628
# actual: 5.0
# predicted: 4.106546525044596
# actual: 3.5
# predicted: 4.016015408278257
# actual: 4.0
# predicted: 3.7665569311638025
# actual: 3.5
# predicted: 4.056028947825016
# actual: 3.5
# predicted: 3.0053607767612536
# actual: 3.0
# predicted: 3.994223325695907
# actual: 5.0
# predicted: 3.854858039915291
# actual: 3.0
# predicted: 4.0813704324106315
# actual: 4.0
# predicted: 3.4904073747157724
# actual: 4.0
# predicted: 2.825334363692699
# actual: 3.5
# predicted: 4.207534008865997
# actual: 5.0
# predicted: 4.140409561007669
# actual: 4.5
# predicted: 3.4087668443620576
# actual: 3.5
# predicted: 3.318426296345446
# actual: 3.5
# predicted: 4.641031636136985
# actual: 5.0
# predicted: 3.780693335656517
# actual: 5.0
# predicted: 3.5864792964192413
# actual: 3.5
# predicted: 4.341267486291283
# actual: 3.5
# predicted: 3.9980799729140446
# actual: 4.5
# predicted: 3.8978081106144673
# actual: 5.0
# predicted: 3.0373786074207176
# actual: 2.0
# predicted: 4.077998487379746
# actual: 4.0
# predicted: 3.5432206121615595
# actual: 3.5
# predicted: 3.687539037935832
# actual: 3.0
# predicted: 4.048059005041801
# actual: 5.0
# predicted: 3.791682090270635
# actual: 2.0
# predicted: 3.8702347570570343
# actual: 5.0
# predicted: 3.6440498773586523
# actual: 2.5
# predicted: 3.8493911505029943
# actual: 4.0
# predicted: 3.981829470677007
# actual: 4.0
# predicted: 4.146693694069571
# actual: 5.0
# predicted: 4.081647308178107
# actual: 4.0
# predicted: 3.89154479415591
# actual: 3.0
# predicted: 4.226493174337188
# actual: 5.0
# predicted: 3.902602208951518
# actual: 5.0
# predicted: 2.8135574259813856
# actual: 4.0
# predicted: 3.9847170439136184
# actual: 5.0
# predicted: 4.013751423324907
# actual: 5.0
# predicted: 4.096963625227849
# actual: 3.5
# predicted: 3.582484359140633
# actual: 4.0
# predicted: 4.219207692424796
# actual: 4.0
# predicted: 4.918070038853527
# actual: 4.5
# predicted: 4.738493880488477
# actual: 4.5
# predicted: 4.102218513689827
# actual: 5.0
# predicted: 4.135707333194554
# actual: 4.5
# predicted: 2.7795484351699367
# actual: 1.0
# predicted: 4.003891117331684
# actual: 5.0
# predicted: 3.189283049528466
# actual: 3.5
# predicted: 4.4166031483231
# actual: 5.0
# predicted: 3.3011416479538873
# actual: 4.0
# predicted: 3.7828331855556385
# actual: 5.0
# predicted: 4.059448251844083
# actual: 4.0
# predicted: 3.267321623416914
# actual: 2.0
# predicted: 3.8559646277082087
# actual: 4.0
# predicted: 3.767592492952447
# actual: 4.0
# predicted: 3.5403264451572407
# actual: 1.0
# predicted: 3.6264195846380995
# actual: 2.0
# predicted: 4.063204297076488
# actual: 4.0
# predicted: 3.483658029382915
# actual: 4.0
# predicted: 3.7392664450826296
# actual: 5.0
# predicted: 3.2789342745501266
# actual: 5.0
# predicted: 3.3798044097642688
# actual: 4.0
# predicted: 3.7196318339663557
# actual: 4.0
# predicted: 4.127901515829535
# actual: 5.0
# predicted: 3.461503658303556
# actual: 4.0
# predicted: 4.031252915343142
# actual: 5.0
# predicted: 4.91548372533695
# actual: 4.0
# predicted: 3.787188710097322
# actual: 4.0
# predicted: 4.371277059484686
# actual: 5.0
# predicted: 3.3583911175156955
# actual: 3.0
# predicted: 4.0059892349104445
# actual: 4.5
# predicted: 3.4725351397166246
# actual: 2.0
# predicted: 4.146719184337869
# actual: 4.5
# predicted: 3.6261590048193812
# actual: 3.0
# predicted: 3.5975332015576815
# actual: 4.0
# predicted: 3.9792179492836355
# actual: 5.0
# predicted: 3.66494823279848
# actual: 3.5
# predicted: 2.943296080887441
# actual: 2.0
# predicted: 3.8111719783659117
# actual: 4.5
# predicted: 3.594674412452117
# actual: 4.5
# predicted: 4.059456541846933
# actual: 4.0
# predicted: 4.029192072101932
# actual: 4.0
# predicted: 3.6969092946696347
# actual: 4.0
# predicted: 2.925738664379577
# actual: 3.0
# predicted: 2.9342096550410144
# actual: 3.0
# predicted: 3.8878883957958474
# actual: 3.5
# predicted: 3.877436913185146
# actual: 5.0
# predicted: 2.8180067252832957
# actual: 2.0
# predicted: 1.8686924660991688
# actual: 2.0
# predicted: 3.7738857634578142
# actual: 2.0
# predicted: 4.288271885765017
# actual: 4.0
# predicted: 3.3080054322995625
# actual: 4.0
# predicted: 3.9737673625169925
# actual: 4.0
# predicted: 4.004372958205554
# actual: 2.5
# predicted: 4.076488628964975
# actual: 5.0
# predicted: 4.4997100846791485
# actual: 4.5
# predicted: 3.336851954640397
# actual: 2.0
# predicted: 3.0951248756602734
# actual: 4.0
# predicted: 2.743413927589727
# actual: 1.0
# predicted: 3.859412846432849
# actual: 4.5
# predicted: 3.755433437593842
# actual: 1.0
# predicted: 2.522477936772022
# actual: 2.5
# predicted: 4.168183011037718
# actual: 4.0
# predicted: 3.609325358677435
# actual: 4.0
# predicted: 3.2999617038463076
# actual: 3.0
# predicted: 3.779235540210295
# actual: 4.0
# predicted: 3.216691632123625
# actual: 4.5
# predicted: 4.144900216424189
# actual: 5.0
# predicted: 3.8535601865566824
# actual: 3.0
# predicted: 4.4677944635476035
# actual: 4.5
# predicted: 4.011706620576014
# actual: 4.0
# predicted: 3.851927608962919
# actual: 3.0
# predicted: 3.3284279326824158
# actual: 3.5
# predicted: 3.4389734337293065
# actual: 3.5
# predicted: 3.33965403071458
# actual: 4.0
# predicted: 3.601359964784414
# actual: 2.0
# predicted: 3.917470822692812
# actual: 3.5
# predicted: 4.265266756401694
# actual: 4.5
# predicted: 3.7173993213200474
# actual: 5.0
# predicted: 2.780460744243089
# actual: 2.0
# predicted: 3.0667100986935756
# actual: 4.0
# predicted: 3.5025280479888656
# actual: 3.0
# predicted: 3.7542204026317525
# actual: 4.0
# predicted: 2.5793422865043483
# actual: 3.0
# predicted: 3.6699858259756954
# actual: 3.5
# predicted: 3.7299644574169464
# actual: 5.0
# predicted: 4.383551094045524
# actual: 4.0
# predicted: 4.200625604757426
# actual: 4.0
# predicted: 3.9999815043613958
# actual: 4.5
# predicted: 4.066567266108597
# actual: 4.0
# predicted: 4.315786208328676
# actual: 4.0
# predicted: 3.983160899683944
# actual: 5.0
# predicted: 3.2154381054690218
# actual: 5.0
# predicted: 4.211749677423612
# actual: 4.5
# predicted: 3.5047411266090127
# actual: 4.5
# predicted: 4.153992649191398
# actual: 2.5
# predicted: 3.732998473849363
# actual: 4.0
# predicted: 3.7302121409782014
# actual: 5.0
# predicted: 4.67907185169498
# actual: 5.0
# predicted: 4.0300595080251975
# actual: 4.0
# predicted: 3.4060007834166193
# actual: 4.0
# predicted: 3.8469471904798427
# actual: 4.5
# predicted: 3.9587040923254384
# actual: 5.0
# predicted: 3.5808973940421884
# actual: 5.0
# predicted: 3.6980014296720776
# actual: 3.5
# predicted: 3.8604320518995423
# actual: 3.0
# predicted: 4.087318801895733
# actual: 3.5
# predicted: 4.334476908948295
# actual: 5.0
# predicted: 3.8044769256954125
# actual: 5.0
# predicted: 3.6948921894107167
# actual: 4.0
# predicted: 3.802027286066829
# actual: 4.0
# predicted: 3.443545342293848
# actual: 3.5
# predicted: 4.5035269952208505
# actual: 4.0
# predicted: 3.58443444435522
# actual: 4.0
# predicted: 4.3112293152989345
# actual: 5.0
# predicted: 2.8326707520395527
# actual: 3.5
# predicted: 4.081229239797436
# actual: 4.0
# predicted: 4.090833981766016
# actual: 5.0
# predicted: 2.977052680052861
# actual: 3.0
# predicted: 3.7129999881460587
# actual: 4.0
# predicted: 3.734254236834417
# actual: 3.5
# predicted: 4.566007887352695
# actual: 4.5
# predicted: 3.441767862530687
# actual: 3.0
# predicted: 3.2687445450542905
# actual: 3.0
# predicted: 3.6739219301964767
# actual: 5.0
# predicted: 3.872164004721287
# actual: 5.0
# predicted: 4.1815166377193655
# actual: 4.5
# predicted: 3.9959081976986783
# actual: 2.0
# predicted: 4.227521095285329
# actual: 4.5
# predicted: 3.5295906335005016
# actual: 2.0
# predicted: 4.605631933109917
# actual: 5.0
# predicted: 3.5154882165813457
# actual: 3.5
# predicted: 3.4096176734197656
# actual: 4.5
# predicted: 3.767437315721109
# actual: 4.0
# predicted: 3.4450263683179894
# actual: 4.0
# predicted: 3.551115022773466
# actual: 4.0
# predicted: 2.9120969617075185
# actual: 3.0
# predicted: 3.1660859920613413
# actual: 3.5
# predicted: 4.124574081155938
# actual: 4.0
# predicted: 3.9633062160587214
# actual: 5.0
# predicted: 3.856834161926107
# actual: 4.0
# predicted: 3.609432467634759
# actual: 3.0
# predicted: 3.567808946885492
# actual: 3.0
# predicted: 3.563108407709034
# actual: 4.0
# predicted: 3.2861361224231076
# actual: 3.0
# predicted: 3.4499959797822646
# actual: 3.0
# predicted: 3.4591062237665193
# actual: 5.0
# predicted: 5.039333887895264
# actual: 4.0
# predicted: 4.344056825114967
# actual: 3.5
# predicted: 4.0602518230196605
# actual: 4.0
# predicted: 4.495639471775908
# actual: 5.0
# predicted: 3.878962956155145
# actual: 3.5
# predicted: 4.0876302012684675
# actual: 3.0
# predicted: 3.831841926850099
# actual: 5.0
# predicted: 3.6828766756673335
# actual: 4.0
# predicted: 4.1818428633386695
# actual: 4.0
# predicted: 3.506088959063544
# actual: 4.0
# predicted: 4.41934905548756
# actual: 3.0
# predicted: 4.261596355356239
# actual: 4.5
# predicted: 3.836115801123795
# actual: 4.0
# predicted: 3.9723907212717657
# actual: 3.0
# predicted: 3.571559106892221
# actual: 5.0
# predicted: 3.7333877836601284
# actual: 2.0
# predicted: 4.463581783932245
# actual: 5.0
# predicted: 4.02966885055265
# actual: 4.0
# predicted: 4.218034225054247
# actual: 4.5
# predicted: 3.1074339089455316
# actual: 2.5
# predicted: 4.479081880230629
# actual: 5.0
# predicted: 3.673276765678657
# actual: 4.5
# predicted: 3.7973594748556994
# actual: 3.5
# predicted: 3.8680059901774237
# actual: 4.0
# predicted: 4.254978262302526
# actual: 4.0
# predicted: 3.3749605033905423
# actual: 4.0
# predicted: 3.7203510813669913
# actual: 3.0
# predicted: 3.866774336866536
# actual: 5.0
# predicted: 3.683527345480065
# actual: 3.0
# predicted: 3.646070920949597
# actual: 3.5
# predicted: 3.512275456131441
# actual: 4.0
# predicted: 2.754844195008006
# actual: 1.0
# predicted: 4.184840656370548
# actual: 4.0
# predicted: 3.898521819391624
# actual: 3.0
# predicted: 3.0777175079117916
# actual: 1.0
# predicted: 3.0320395366295845
# actual: 2.5
# predicted: 3.9949097266459987
# actual: 5.0
# predicted: 3.653017860079194
# actual: 4.0
# predicted: 4.403751796722497
# actual: 4.0
# predicted: 3.5123555559013657
# actual: 4.0
# predicted: 3.9239831893978487
# actual: 3.0
# predicted: 3.908835266605074
# actual: 4.5
# predicted: 4.225888724625798
# actual: 3.5
# predicted: 3.9528801435747174
# actual: 3.5
# predicted: 4.5231775293778895
# actual: 4.5
# predicted: 1.5777649727444938
# actual: 2.5
# predicted: 4.0835154086382275
# actual: 4.0
# predicted: 4.195825055889829
# actual: 4.0
# predicted: 3.922002211257715
# actual: 3.5
# predicted: 3.4517167139195535
# actual: 3.0
# predicted: 4.0027323371844
# actual: 3.0
# predicted: 5.1696352049436545
# actual: 5.0
# predicted: 3.4997188536455157
# actual: 4.5
# predicted: 4.242786674857822
# actual: 2.0
# predicted: 3.580786617591141
# actual: 5.0
# predicted: 4.348876445470572
# actual: 4.0
# predicted: 4.419039916761652
# actual: 5.0
# predicted: 4.107065003277949
# actual: 3.0
# predicted: 3.7936149098720806
# actual: 4.0
# predicted: 3.984097612815818
# actual: 5.0
# predicted: 3.5913291550697344
# actual: 2.0
# predicted: 4.275732255799726
# actual: 4.0
# predicted: 4.267727212469013
# actual: 4.0
# predicted: 4.356362998381709
# actual: 4.5
# predicted: 3.0328575303115697
# actual: 4.5
# predicted: 2.906927170977315
# actual: 1.5
# predicted: 4.037925015980646
# actual: 4.5
# predicted: 4.031135365842426
# actual: 4.5
# predicted: 3.9563050453950455
# actual: 3.0
# predicted: 3.9884975821241637
# actual: 3.0
# predicted: 3.5779238253239787
# actual: 4.0
# predicted: 3.545148283483579
# actual: 4.0
# predicted: 3.7121269608181313
# actual: 4.0
# predicted: 3.78101843789954
# actual: 4.0
# predicted: 4.1095828176146
# actual: 5.0
# predicted: 4.265351904722184
# actual: 5.0
# predicted: 3.596282416790134
# actual: 2.0
# predicted: 2.3687831537282875
# actual: 4.0
# predicted: 4.479621266639422
# actual: 4.0
# predicted: 3.9503362815306664
# actual: 4.0
# predicted: 2.4497550643123844
# actual: 4.0
# predicted: 3.1067129363542465
# actual: 2.0
# predicted: 3.5145840223574427
# actual: 3.0
# predicted: 3.196474205605155
# actual: 3.0
# predicted: 2.9687476301027518
# actual: 4.0
# predicted: 3.6151636652494035
# actual: 2.0
# predicted: 3.7143142318956524
# actual: 4.0
# predicted: 4.045057227507943
# actual: 4.5
# predicted: 4.425871179741435
# actual: 4.0
# predicted: 4.281182297479545
# actual: 4.0
# predicted: 3.417687365361237
# actual: 3.0
# predicted: 4.043586780563711
# actual: 4.5
# predicted: 2.2273631384693537
# actual: 2.5
# predicted: 3.4291508000045723
# actual: 3.5
# predicted: 4.3292999272297585
# actual: 2.5
# predicted: 4.166076412210311
# actual: 4.0
# predicted: 3.563834840367893
# actual: 5.0
# predicted: 4.243906252629136
# actual: 5.0
# predicted: 3.865309785929618
# actual: 4.5
# predicted: 3.7261469247896826
# actual: 5.0
# predicted: 3.7124994338785897
# actual: 4.0
# predicted: 4.134966482136595
# actual: 3.0
# predicted: 3.8672212349412667
# actual: 0.5
# predicted: 3.956805709910093
# actual: 4.0
# predicted: 3.2908998822656503
# actual: 4.0
# predicted: 3.5888399071828836
# actual: 3.5
# predicted: 3.476146368256017
# actual: 4.5
# predicted: 3.948024685622283
# actual: 4.0
# predicted: 4.282923224235593
# actual: 2.5
# predicted: 3.4699612359321432
# actual: 5.0
# predicted: 3.508858241601814
# actual: 5.0
# predicted: 2.7693311722131484
# actual: 2.5
# predicted: 3.3581237803496435
# actual: 4.0
# predicted: 3.133296408719124
# actual: 1.0
# predicted: 4.168194140244623
# actual: 5.0
# predicted: 3.8022589458620915
# actual: 4.0
# predicted: 4.081508930390424
# actual: 4.0
# predicted: 3.7158425802542454
# actual: 4.0
# predicted: 5.05276510414739
# actual: 4.5
# predicted: 3.9044641370621704
# actual: 4.0
# predicted: 2.9575894330052255
# actual: 4.0
# predicted: 3.6765544864196213
# actual: 3.0
# predicted: 4.514786169730222
# actual: 5.0
# predicted: 3.8781955071045555
# actual: 4.0
# predicted: 3.7402136296490984
# actual: 4.0
# predicted: 3.5301228282947963
# actual: 3.0
# predicted: 4.741800583784498
# actual: 4.0
# predicted: 3.7216831139612636
# actual: 4.0
# predicted: 3.5394074782101277
# actual: 4.0
# predicted: 4.255680359033187
# actual: 5.0
# predicted: 4.336962872673027
# actual: 5.0
# predicted: 3.5220644430787433
# actual: 2.5
# predicted: 3.21281635757815
# actual: 3.0
# predicted: 3.90093902734327
# actual: 4.0
# predicted: 4.13507811860287
# actual: 4.0
# predicted: 4.378730798008043
# actual: 5.0
# predicted: 4.450262103362396
# actual: 5.0
# predicted: 4.087144413138597
# actual: 4.0
# predicted: 2.8496205779569475
# actual: 2.0
# predicted: 3.551433712928147
# actual: 5.0
# predicted: 4.194723075094494
# actual: 4.0
# predicted: 4.5097894210946645
# actual: 4.5
# predicted: 4.067436761112049
# actual: 4.0
# predicted: 4.293142497180909
# actual: 3.5
# predicted: 3.547200754367965
# actual: 3.0
# predicted: 3.364571475723983
# actual: 3.5
# predicted: 4.410888426190747
# actual: 5.0
# predicted: 4.618616215358138
# actual: 3.0
# predicted: 3.6576742615856563
# actual: 2.5
# predicted: 3.3474799786202665
# actual: 5.0
# predicted: 4.067361433386056
# actual: 5.0
# predicted: 4.4046881502157795
# actual: 5.0
# predicted: 3.900159387702579
# actual: 3.0
# predicted: 4.359619596356794
# actual: 4.0
# predicted: 3.8290370550698736
# actual: 3.5
# predicted: 2.999324414346782
# actual: 3.5
# predicted: 4.584295663782489
# actual: 5.0
# predicted: 4.124398555067234
# actual: 5.0
# predicted: 3.877325508459368
# actual: 4.0
# predicted: 4.458922914330305
# actual: 5.0
# predicted: 4.186204986054188
# actual: 4.5
# predicted: 3.236816628726649
# actual: 4.0
# predicted: 3.50649660365134
# actual: 5.0
# predicted: 3.4861076780986107
# actual: 3.0
# predicted: 3.572693804340473
# actual: 4.0
# predicted: 4.289281820382398
# actual: 4.5
# predicted: 3.070092716163387
# actual: 2.0
# predicted: 3.8766684252712063
# actual: 3.5
# predicted: 3.8014983719496636
# actual: 3.0
# predicted: 3.6033943331237777
# actual: 3.0
# predicted: 2.8292310221529253
# actual: 3.5
# predicted: 4.181575683934735
# actual: 5.0
# predicted: 4.241585604338552
# actual: 4.0
# predicted: 3.5080817881889383
# actual: 4.0
# predicted: 3.6730119963747856
# actual: 2.0
# predicted: 4.107118170614218
# actual: 4.0
# predicted: 4.337919551493002
# actual: 5.0
# predicted: 3.986423740397637
# actual: 5.0
# predicted: 3.062398954596129
# actual: 5.0
# predicted: 3.6098853005879423
# actual: 2.5
# predicted: 3.8083474721594732
# actual: 3.0
# predicted: 4.418417524898427
# actual: 4.0
# predicted: 4.334614791389326
# actual: 4.0
# predicted: 3.5604881295830313
# actual: 3.0
# predicted: 4.425275123382585
# actual: 5.0
# predicted: 4.0713068943254465
# actual: 4.0
# predicted: 3.61242224993718
# actual: 5.0
# predicted: 4.147649202107207
# actual: 5.0
# predicted: 4.580850893201408
# actual: 5.0
# predicted: 4.12947413127312
# actual: 5.0
# predicted: 3.7010422976215316
# actual: 5.0
# predicted: 3.3961086926269064
# actual: 3.0
# predicted: 4.30979858880155
# actual: 5.0
# predicted: 3.3727072290550324
# actual: 4.0
# predicted: 3.251110994359619
# actual: 4.0
# predicted: 3.9699546253568916
# actual: 3.0
# predicted: 3.382139984774066
# actual: 4.0
# predicted: 4.326540111501242
# actual: 5.0
# predicted: 4.16543358714147
# actual: 5.0
# predicted: 3.720396546835265
# actual: 4.0
# predicted: 3.9327665695466525
# actual: 4.0
# predicted: 3.816625695285138
# actual: 0.5
# predicted: 2.45813525339684
# actual: 3.0
# predicted: 2.882109178966559
# actual: 2.5
# predicted: 4.308109296241675
# actual: 4.0
# predicted: 3.706094495852083
# actual: 3.0
# predicted: 3.2485513265528017
# actual: 4.0
# predicted: 3.5833058583026722
# actual: 3.0
# predicted: 3.502712667974428
# actual: 4.0
# predicted: 3.4427562077311262
# actual: 2.5
# predicted: 3.7923447873705216
# actual: 4.0
# predicted: 2.211255399435065
# actual: 2.5
# predicted: 3.4809573637619313
# actual: 3.0
# predicted: 4.489478063013447
# actual: 5.0
